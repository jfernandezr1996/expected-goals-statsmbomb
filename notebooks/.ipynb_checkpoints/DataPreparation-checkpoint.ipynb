# %% [markdown]
# # Packages
# ---

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from IPython.display import YouTubeVideo
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Data Cleaning
# ---

# %%
df = pd.read_csv('../output_files/LaLiga_WorldCup/data_wranling.csv', sep=";")

# %%
df_NaN = pd.DataFrame(df.isna().sum(), columns=['NaN_values'])
df_NaN[df_NaN.NaN_values > 0]
# Out:
#                   NaN_values
# angle                      1
# xGoalkeeper               14
# yGoalkeeper               14
# underPressure          11412
# lastActionPlayer          33

# %% [markdown]
# ## `lastActionPlayer`

# %%
df_fillna = df[df.lastActionPlayer.isnull()]
df_fillna[['lastAction','lastActionPlayer','lastActionPossesionTeam']]
# Out:
#             lastAction lastActionPlayer lastActionPossesionTeam
# 214     Tactical Shift              NaN                  Getafe
# 409          Camera On              NaN               Barcelona
# 496          Camera On              NaN                  Girona
# 637    Injury Stoppage              NaN        Deportivo Alavés
# 2590    Tactical Shift              NaN               Barcelona
# 4479    Tactical Shift              NaN               Barcelona
# 5579    Tactical Shift              NaN               Barcelona
# 5965    Tactical Shift              NaN               Barcelona
# 6191    Tactical Shift              NaN               Barcelona
# 6868    Tactical Shift              NaN               Barcelona
# 7224    Tactical Shift              NaN               Barcelona
# 8206    Tactical Shift              NaN               Barcelona
# 8815    Tactical Shift              NaN               Barcelona
# 9247    Tactical Shift              NaN               Barcelona
# ...

# %% [markdown]
# > We note that some of the missing records correspond to tactical changes (formation changes) that cannot be fixed to a player. Others correspond to actions not captured by the camera or the start of the second part. We decided to eliminate these instances.

# %%
df = df.dropna(how='any', subset=['lastActionPlayer'])

# %% [markdown]
# ## `keyPassType`

# %%
df['keyPassType'].value_counts()
# Out:
# Ground Pass    5447
# None           3924
# High Pass      3207
# Low Pass       1098
# Name: keyPassType, dtype: int64

# %%
df['keyPassType'] = df['keyPassType'].fillna('None')

# %% [markdown]
# ## `underPressure`
# The field will be converted to binary, so that when the player is not under pressure it takes the value 0 and otherwise 1.

# %%
df['underPressure'] = df['underPressure'].fillna(0)

# %% [markdown]
# ## `angle`

# %%
df[df['angle'].isnull()][['x','y','angle','distance','player','opponentTeam','result','season',
                          'playerAssisted','lastAction','firstTime']]
# Out:
#           x     y  angle  distance                    player opponentTeam  \
# 7594  120.0  43.7    NaN       3.7  Luis Alberto Suárez Díaz   Celta Vigo
#
#      result     season playerAssisted     lastAction  firstTime
# 7594   Goal  2015/2016           None  Ball Recovery       True

# %% [markdown]
# > We observe that the x-coordinate is 120 which indicates that the ball was on the goal line and therefore when calculating the angle the calculation was not correct.

# %%
a = np.sqrt((120-120)**2+(43.7-36)**2)
b = np.sqrt((120-120)**2+(43.7-44)**2)
angle = np.degrees(np.arccos(round((a**2+b**2-64)/(2*a*b))))
print("180º angle = flat angle: ", angle)

df['angle'] = df['angle'].fillna(angle)
# Out:
# 180º angle = flat angle:  180.0

# %% [markdown]
# ## `xGoalkeeper - yGoalkeeper`
#
# As seen in the building code of these fields, these 'NaN' values refer to those situations where the goalkeeper is not in the box surrounding the player with ball possession. In all these situations, it is understood that the goalkeeper was far from the player in possession. Accessing these values, we can see that only 1 shot was a goal, which means that these are situations with little probability of success (as indicated by the `xG` field).
#
# Well, **how do we decide to impute these 'NaN' values on the goalkeeper's coordinates?**
#
# Previously, we decided to analyze the relationships between the goalkeeper and the shot put coordinates.
#
# ### Shots where the player is closer to the goal than the opposing team's goalkeeper

# %%
df[(df['xGoalkeeper'] < df['x']) & (df['xGoalkeeper']<100)][['x','y','xGoalkeeper','yGoalkeeper','result','xG','player',
                                   'bodyPart', 'playerTeam', 'opponentTeam', 'season', 'competition']]
# Out:
#            x     y  xGoalkeeper  yGoalkeeper result        xG  \
# 3850   112.1  41.8         96.1         41.7   Goal  0.846318
# 9868   114.4  41.7         93.7         31.0   Goal  0.775170
# 12700  113.0  40.0         87.0         50.0   Goal  0.869226
# 13574  116.0  32.0         62.0         41.0   Goal  0.780189
#
#                                player    bodyPart   playerTeam opponentTeam  \
# 3850   Lionel Andrés Messi Cuccittini   Left Foot    Barcelona       Málaga
# 9868                    Thierry Henry  Right Foot    Barcelona  Real Murcia
# 12700            M"Baye Babacar Niang  Right Foot      Senegal       Poland
# 13574                   Heung-Min Son   Left Foot  South Korea      Germany
#
#           season     competition
# 3850   2011/2012         La Liga
# 9868   2007/2008         La Liga
# 12700       2018  FIFA World Cup
# 13574       2018  FIFA World Cup

# %% [markdown]
# * We watched the goal by **Heung-Min Son**: https://www.youtube.com/watch?v=S2XBdgEXr5c

# %% [markdown]
# ### `NaN` values
#
# When assigning the NaN values, we assume that it is not a shot from a player on his goal, otherwise we would understand that the goalkeeper would be close to that player, so we assume that the goalkeeper is on his goal.

# %%
df[df['xGoalkeeper'].isnull()]['result'].value_counts()
# Out:
# Saved      7
# Blocked    3
# Goal       1
# Wayward    1
# Off T      1
# Name: result, dtype: int64

# %% [markdown]
# #### Goals for which the goalkeeper's location is unknown

# %%
df[(df['xGoalkeeper'].isnull()) & (df['result'] == 'Goal')][['x', 'y', 'angle', 'competition', 'season', 'player', 'xG',
                                                             'playerTeam', 'bodyPart', 'xGoalkeeper', 'yGoalkeeper', 
                                                             'opponentTeam', 'underPressure', 'lastAction', 'playerAssisted']]
# Out:
#           x     y  angle competition     season                    player  \
# 1256  114.9  47.3   32.8     La Liga  2016/2017  Francisco Alcácer García
#
#             xG playerTeam    bodyPart  xGoalkeeper  yGoalkeeper opponentTeam  \
# 1256  0.266493  Barcelona  Right Foot          NaN          NaN      Osasuna
#
#       underPressure lastAction playerAssisted
# 1256            0.0      Carry     Arda Turan

# %% [markdown]
# https://www.youtube.com/watch?v=3LQvs8lj9D4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > We observe that the goalkeeper in this case is on the ground far from the ball and therefore her position has not been detected, which is in the center of the small area. Podemos identificar su posición como [118, 45]

# %% [markdown]
# #### Saved shots for which the location of the goalkeeper is unknown
#
# > For those launches that had a `saved` result we decided to impute the missing values in the goalkeeper's coordinates using the values of `xEndLocation` and `yEndLocation`.

# %%
df[df['xGoalkeeper'].isnull()][['x','y','result','xEndLocation', 'yEndLocation', 'player','bodyPart',
                                'xG','date','competition','season','playerTeam','opponentTeam']]\
                    .sort_values(by='xG', ascending=False).head()
# Out:
#           x     y   result  xEndLocation  yEndLocation  \
# 1256  114.9  47.3     Goal         120.0          38.5
# 7748  114.9  29.5    Saved         118.1          35.3
# 8315  114.8  32.2    Saved         119.1          36.4
# 5850  111.4  36.2    Saved         119.6          42.3
# 2386  107.1  38.2  Blocked         108.0          39.1
#
#                          player    bodyPart        xG        date competition  \
# 1256   Francisco Alcácer García  Right Foot  0.266493  2017-04-26     La Liga
# 7748     Anderson Luís de Souza   Left Foot  0.236569  2004-10-16     La Liga
# 8315     Ismael Marchal Razquín        Head  0.174257  2007-06-17     La Liga
# 5850  Jean-Sylvain Claude Babin        Head  0.167703  2014-09-27     La Liga
# 2386    Juan Manuel Mata García        Head  0.121726  2009-10-17     La Liga
#
#          season           playerTeam opponentTeam
# 1256  2016/2017            Barcelona      Osasuna
# 7748  2004/2005            Barcelona     Espanyol
# ...

# %% [markdown]
# #### Impute NaN values
#
# For the rest of the cases we will use the coordinates `[118,40]`

# %%
def impute_NaN_values_X(xGoalkeeper, xEndLocation, result):
    if pd.isna(xGoalkeeper):
        if result == 'Saved':
            return xEndLocation
        else: 
            return 118
    else:
        return xGoalkeeper
    
def impute_NaN_values_Y(yGoalkeeper, yEndLocation, result):
    if pd.isna(yGoalkeeper):
        if result == 'Saved':
            return yEndLocation
        else:
            if result == 'Goal':
                return 45
            else:
                return 40
    else:
        return yGoalkeeper

# %%
df['xGoalkeeper'] = df[['result', 'xEndLocation', 'xGoalkeeper']].apply(
    lambda x: impute_NaN_values_X(x[2],x[1],x[0]), axis=1)
df['yGoalkeeper'] = df[['result', 'yEndLocation', 'yGoalkeeper']].apply(
    lambda x: impute_NaN_values_Y(x[2],x[1],x[0]), axis=1)

# %%
print("Número de registros nulos:", df.isna().sum().sum())
# Out:
# Número de registros nulos: 0

# %%
df.to_csv('../output_files/LaLiga_WorldCup/data_cleaning.csv', sep=";", index=False)

# %% [markdown]
# # Feature Engineering and relationship to the target variable
# ---
# We will carry out a treatment on some of our variables as well as the possibility of incorporating new fields. **The analysis of these variables is aimed at simplifying the levels of categories that can be taken by the different categorical variables that simplify the patterns acquired by the machine learning models that we will apply in the following section.**
#
# We will rely on Bejamin Pavard's next goal in the World Cup for the treatment of the features.
#
# * **Goal Benjamin Pavard against Argentina FIFA World Cup**

# %%
YouTubeVideo('hK7BjNE2TTA')

# %%
def plot_categorical_variables(df, attribute):
    if attribute == 'target':
        df_levels = pd.DataFrame(df[attribute].value_counts(normalize=True)).sort_index()
        fig = go.Figure(go.Bar(x=df_levels.index, y=df_levels[attribute], marker_color='chocolate', name='target'))
        fig.update_layout(title_text='Target Class Proportions', xaxis_title='target', yaxis_title='percentage')
    else:
        df_attribute = df[[attribute, 'target']]
        list_levels = list(df_attribute[attribute].unique())
        fig = go.Figure()
        for level in list_levels:
            level_df = pd.DataFrame(df_attribute[df_attribute[attribute]==level]['target'].value_counts()).sort_index()
            fig.add_trace(go.Bar(x=list(level_df.index), y=level_df['target'], name=level))
        fig.update_layout(xaxis_title = 'target', yaxis_title = 'count', 
                          title_text = 'Categorical Attribute (' + attribute + ') levels frecuency based on the target variable')
    fig.show()

# %%
attributes_to_explain = ['x','y','result','situation', 'playerPosition', 'playerAssisted', 'bodyPart', 'playType', 
                          'firstTime','isCrossKeyPass', 'isCutBackKeyPass', 'xG', 'competition']
df[(df.competition=='FIFA World Cup') & (df.result == 'Goal') & (df.firstTime) & (df.player == 'Benjamin Pavard')]\
        [attributes_to_explain]
# Out:
#            x     y result     situation playerPosition      playerAssisted  \
# 12569  100.0  56.0   Goal  Regular Play     Right Back  Lucas Hernández Pi
#
#          bodyPart   playType  firstTime  isCrossKeyPass  isCutBackKeyPass  \
# 12569  Right Foot  Open Play       True            True             False
#
#              xG     competition
# 12569  0.027012  FIFA World Cup

# %% [markdown]
# ## `target`
#
# We must not forget what our objective is: to predict whether a shot will be a goal or not as well as its probability of success based on a series of characteristics.
#
# So, we must build our variable to predict, that is, the label of each example that tells us if the throw has been a goal or not. To do this, we use the attribute `result`.

# %%
df['target'] = df['result'].apply(lambda x: 'isGoal' if x == 'Goal' else 'notGoal')

plot_categorical_variables(df, 'target')
# Out:
# <div>                            <div id="e748c10a-be0f-4135-8877-79371a54d18b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e748c10a-be0f-4135-8877-79371a54d18b")) {                    Plotly.newPlot(                        "e748c10a-be0f-4135-8877-79371a54d18b",                        [{"marker": {"color": "chocolate"}, "name": "target", "type": "bar", "x": ["isGoal", "notGoal"], "y": [0.13307984790874525, 0.8669201520912547]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor
# ...

# %% [markdown]
# ## `firstTime`
#
# This is a variable that indicates whether the shot was fired at the first touch as Benjamin Pavard's Goal. We show below two goals in which this field equals `True` and another one in which it equals `False`. Therefore, we decided to consider two categories for this new variable (`firstTimeCarry`): `firstTime` and `carry` indicating that it is a drive.

# %%
df['firstTimeCarry'] = df['firstTime'].apply(lambda x: 'firstTime' if x else 'carry')

plot_categorical_variables(df, 'firstTimeCarry')
# Out:
# <div>                            <div id="4ec84ac6-47cb-4e97-a4b7-9d3cf2582bc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ec84ac6-47cb-4e97-a4b7-9d3cf2582bc8")) {                    Plotly.newPlot(                        "4ec84ac6-47cb-4e97-a4b7-9d3cf2582bc8",                        [{"name": "carry", "type": "bar", "x": ["isGoal", "notGoal"], "y": [1101, 8596]}, {"name": "firstTime", "type": "bar", "x": ["isGoal", "notGoal"], "y": [719, 3260]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aa
# ...

# %% [markdown]
# ## `isCrossKeyPass, isCutBackKeyPass`
#
# By definition of the manuals:
# * `Cross Pass`: cross from the wing.
# * `Cut-Back Pass`: pass back from the bye-line.
#
# Looking at the video, we see that the shot is preceded by a center by Lucas Hernandez, which is indicated by the boolean value `True` in `isCrossKeyPass`.
#
# We decided to create a new variable that is `previousKeyPass` with the categories: `cross`, `cutback` and `forward`, covering the different possibilities of a type of pass.

# %%
def cat_previous_pass(x1,x2):
    if x1:
        return 'cut-back'
    elif x2:
        return 'cross'
    else:
        return 'forward'
    
df['previousKeyPass'] = df[['isCrossKeyPass','isCutBackKeyPass']].apply(lambda x: cat_previous_pass(x[1],x[0]), axis=1)

plot_categorical_variables(df, 'previousKeyPass')
# Out:
# <div>                            <div id="d1b5d0db-227d-40c2-a3e5-44f9a1a0a556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1b5d0db-227d-40c2-a3e5-44f9a1a0a556")) {                    Plotly.newPlot(                        "d1b5d0db-227d-40c2-a3e5-44f9a1a0a556",                        [{"name": "forward", "type": "bar", "x": ["isGoal", "notGoal"], "y": [1500, 10209]}, {"name": "cross", "type": "bar", "x": ["isGoal", "notGoal"], "y": [279, 1432]}, {"name": "cut-back", "type": "bar", "x": ["isGoal", "notGoal"], "y": [41, 215]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"l
# ...

# %% [markdown]
# ## `playerPosition`

# %%
new_positions = {'Goalkeeper': 'Goalkeeper', 'Left Back': 'Defender', 'Left Center Back': 'Defender', 
                 'Right Center Back': 'Defender', 'Right Back': 'Defender', 'Right Wing Back': 'Defender', 
                 'Left Wing Back': 'Defender', 'Center Back': 'Defender', 'Left Center Midfield': 'Midfielder', 
                 'Right Center Midfield': 'Midfielder', 'Center Attacking Midfield': 'Midfielder', 
                 'Left Midfield': 'Midfielder', 'Right Midfield': 'Midfielder', 'Center Defensive Midfield': 'Midfielder', 
                 'Left Defensive Midfield': 'Midfielder', 'Right Defensive Midfield': 'Midfielder', 
                 'Left Attacking Midfield': 'Midfielder', 'Right Attacking Midfield': 'Midfielder', 
                 'Center Midfield': 'Midfielder', 'Center Forward': 'Striker', 'Right Center Forward': 'Striker', 
                 'Left Center Forward': 'Striker', 'Secondary Striker': 'Striker', 'Left Wing': 'Striker', 
                 'Right Wing': 'Striker'}


df['playerPosition'] = df['playerPosition'].apply(lambda x: new_positions[x])
plot_categorical_variables(df, 'playerPosition')
# Out:
# <div>                            <div id="c2420aef-9d64-4a66-a0a1-2fada6e3f541" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2420aef-9d64-4a66-a0a1-2fada6e3f541")) {                    Plotly.newPlot(                        "c2420aef-9d64-4a66-a0a1-2fada6e3f541",                        [{"name": "Striker", "type": "bar", "x": ["isGoal", "notGoal"], "y": [1249, 6496]}, {"name": "Midfielder", "type": "bar", "x": ["isGoal", "notGoal"], "y": [383, 3611]}, {"name": "Defender", "type": "bar", "x": ["isGoal", "notGoal"], "y": [188, 1748]}, {"name": "Goalkeeper", "type": "bar", "x": ["notGoal"], "y": [1]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color"
# ...

# %% [markdown]
# ## `competition, season`

# %%
df['competitionSeason'] = df[['competition','season']].apply(lambda x: x[0] + ' (' + x[1] + ')', axis=1)
df['competitionSeason'].value_counts()
# Out:
# FIFA World Cup (2018)    1693
# La Liga (2017/2018)       968
# La Liga (2014/2015)       929
# La Liga (2018/2019)       884
# La Liga (2016/2017)       882
# La Liga (2011/2012)       873
# La Liga (2009/2010)       842
# La Liga (2015/2016)       827
# La Liga (2013/2014)       809
# La Liga (2008/2009)       764
# La Liga (2019/2020)       749
# La Liga (2010/2011)       739
# La Liga (2007/2008)       727
# La Liga (2012/2013)       720
# La Liga (2006/2007)       679
# La Liga (2005/2006)       433
# La Liga (2004/2005)       158
# Name: competitionSeason, dtype: int64

# %% [markdown]
# ## Final dataset

# %%
final_df = df[['x','y','distance','angle','competitionSeason','date','score','playType','situation','player',
               'playerPosition','playerTeam','bodyPart','technique','underPressure','firstTimeCarry',
               'playerAssisted','opponentTeam','homeAway','xGoalkeeper','yGoalkeeper','xEndLocation','yEndLocation',
               'keyPassType','previousKeyPass','playersBetweenShotAndGoal','lastAction','lastActionPlayer',
               'lastActionPossesionTeam','xG','target']]
final_df.head()
# Out:
#        x     y  distance  angle    competitionSeason        date score  \
# 0  106.0  57.8      22.6   12.7  La Liga (2017/2018)  2017-09-09   5-0
# 1   90.0  29.1      31.9   13.5  La Liga (2017/2018)  2017-09-09   5-0
# 2  110.0  39.5      10.0   43.5  La Liga (2017/2018)  2017-09-09   5-0
# 3   96.0  21.1      30.5   11.8  La Liga (2017/2018)  2017-09-09   5-0
# 4  106.0  39.6      14.0   31.9  La Liga (2017/2018)  2017-09-09   5-0
#
#     playType       situation                          player  ...  \
# 0  Open Play     From Corner  Lionel Andrés Messi Cuccittini  ...
# 1  Free Kick  From Free Kick        Luis Alberto Suárez Díaz  ...
# 2  Open Play   From Throw In  Lionel Andrés Messi Cuccittini  ...
# 3  Free Kick  From Free Kick        Luis Alberto Suárez Díaz  ...
# 4  Open Play  From Free Kick                    Ivan Rakitić  ...
#
#   xEndLocation yEndLocation  keyPassType previousKeyPass  \
# 0        120.0         32.2  Ground Pass         forward
# ...

# %%
final_df.to_csv('../output_files/LaLiga_WorldCup/final_df.csv', sep=";", index=False)
